# %% [markdown]
# Session 1

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def is_symmetric(root):
	# U - check if tree is symmetric around its center, return boolean.
    #     #  1
    #      /   \
    #     /     \
    #    2       2
    #   / \     / \
    #  3   4   4   3
    # return True

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
        
def binary_tree_paths(root):
	pass

# %%
# what is the time complecity of mystery_function()?
# you may assume root refers to the root node of a balanced binary search tree
from collections import deque


class TreeNode():
    def __init__(self, value=0, left=None, right=None):
        
        self.value = value
        self.left = left
        self.right = right

def level_order(root):
    # U - return a list of lists, where each list contains the values of the nodes at that level
    #     #  1
    #      /   \
    #     /     \
    #    2       3
    #   / \     
    #  4   5
    if not root:
        return []
    queue = deque([root])
    result = []
    while queue:
        node = queue.popleft()  # Use popleft for FIFO behavior
        result.append(node.value)  # Append the node's value to the result

        if node.left:
            queue.append(node.left)
        if node.right:
            queue.append(node.right)
    return result

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)

root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

output = level_order(root)
print(output)  # Expected output: [1, 2, 3, 4, 5]
# Out:
# [1, 2, 3, 4, 5]

# %%
# Given the root of a binary tree where each node has integer values, return the sum of all left leaves. A leaf is a node with no children. A left leaf that is the left child of another node. As such, a tree with only one node has no left leaves.
# For example, given the following tree:
#     3
#    / \
#   9  20
#      /  \
#     15   7
# Input: root = 3
# Output: 24

class TreeNode():
    def __init__(self, val=0, left=None, right=None):
        
        self.val = val
        self.left = left
        self.right = right

def sum_of_left_leaves(root):
    # U - return the sum of all left leaves in the binary tree
    #     #  3
    #      / \
    #     /   \
    #    9     20
    #         /  \
    #        15   7
    if not root: # if the tree is empty, return 0
        return 0
    if not root.left and not root.right: # if the node is a leaf, return 0
        return 0
    if root.left and not root.left.left and not root.left.right: # if the left child is a leaf, return its value
        return root.left.val + sum_of_left_leaves(root.right)
    # if the left child is not a leaf, recursively call the function on both children
    # and return the sum of the left leaves in both subtrees
    # Note: we do not need to check if the right child is a leaf, as we only want to sum the left leaves
    # and the right child will not contribute to the sum
    return sum_of_left_leaves(root.left) + sum_of_left_leaves(root.right)

# %%
# given the root of a binary search tree where each node has integer values and an integer k, return true if there exist two nodes in the BST such that the sum of their values is equal to k. and false otherwise. 

# For example, given the following tree:
#     5
#    / \
#   3   6
#  / \   \
#  2   4   7
# Input: root = 5, k = 9
# Output: true
# Input: root = 5, k = 28
# Output: false

class TreeNode():
    def __init__(self, val=0, left=None, right=None):
        
        self.val = val
        self.left = left
        self.right = right

def find_target(root, k):
    # U - return true if there exist two nodes in the BST such that the sum of their values is equal to k, and false otherwise
    #     #  5
    #      / \
    #     /   \
    #    3     6
    #   / \     \
    #  2   4     7
    if not root: # if the tree is empty, return false
        return False
    # if the tree is not empty, we can use a stack to traverse the tree and check if there exist two nodes such that their sum is equal to k
    # we can use a set to store the values of the nodes we have seen so far
    stack = [] 
    seen = set()
    stack.append(root)
    # we can use a while loop to traverse the tree using depth-first search (DFS)
    # we can use a stack to keep track of the nodes we need to visit
    while stack:
        # pop the top node from the stack
        # check if the value of the node we popped is equal to k - the value of the node we are looking for
        node = stack.pop()
        if k - node.val in seen:
            return True
        # if the value of the node we popped is not equal to k - the value of the node we are looking for, we can add the value of the node we popped to the set of seen values
        # and push the left and right children of the node we popped to the stack
        seen.add(node.val)

        if node.right:
            stack.append(node.right)
        if node.left:
            stack.append(node.left)
    # if we have traversed the entire tree and have not found two nodes such that their sum is equal to k, we can return false
    return False

# %%
# given the root of a binary tree, return true if the binary tree is perfect and false otherwise. a binary tree is perfect if all internal (non-leaf) nodes have two children and all leaves are at the same level.
# for example, given the following tree:
#     5
#    / \
#   3   6
#  / \ / \
# 2  4 7  8
# Input: root = 5
# Output: true

class TreeNode():
    def __init__(self, val=0, left=None, right=None):
        
        self.val = val
        self.left = left
        self.right = right

def is_perfect(root):
    # U - return true if the binary tree is perfect and false otherwise
    #     #  5
    #      / \
    #     /   \
    #    3     6
    #   / \   / \
    #  2   4 7   8
    if not root: # if the tree is empty, return false
        return False
    # if the tree is not empty, we can use a queue to traverse the tree and check if it is perfect. dont' use any deque or stack, just use a queue
    queue = []
    queue.append(root)
    # we can use a while loop to traverse the tree using breadth-first search (BFS)
    # we can use a queue to keep track of the nodes we need to visit
    while queue:
        # pop the front node from the queue
        node = queue.pop(0)
        # check if the node is a leaf node
        if not node.left and not node.right:
            continue
        # check if the node has two children
        if not node.left or not node.right:
            return False
        # if the node has two children, we can push the left and right children of the node we popped to the queue
        queue.append(node.left)
        queue.append(node.right)
    # if we have traversed the entire tree and have not found any node that does not have two children, we can return true
    return True

# Example usage:
root = TreeNode(5)
root.left = TreeNode(3)
root.right = TreeNode(6)
root.left.left = TreeNode(2)
root.left.right = TreeNode(4)
root.right.left = TreeNode(7)
root.right.right = TreeNode(8)

print(is_perfect(root))  # Expected output: True
# Out:
# True
